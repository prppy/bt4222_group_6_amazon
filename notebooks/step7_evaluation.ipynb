# %% [markdown]
# # Evaluation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import os

data_dir = '/content/drive/MyDrive/bt4222_group_6/bt4222_group_6_amazon/data'
project_dir = '/content/drive/MyDrive/bt4222_group_6/bt4222_group_6_amazon'
results_dir = '/content/drive/MyDrive/bt4222_group_6/bt4222_group_6_amazon/Model Results'

# %%
#step5_1_1- NCF Model: Custom Embedding Full Dataset
cust_emb_full_data_val_results = pd.read_csv(os.path.join(results_dir,"NCF Custom Embedding/Full Model/full_model_validation_results.csv"))
print(cust_emb_full_data_val_results.shape)
print("==============step5_1_1- NCF Model: Custom Embedding Full Dataset Validation Results===============")
display(cust_emb_full_data_val_results.head())


cust_emb_by_full_data_test_results = pd.read_csv(os.path.join(results_dir,"NCF Custom Embedding/Full Model/full_model_testing_results.csv"))
print(cust_emb_by_full_data_test_results.shape)
print("==============step5_1_1- NCF Model: Custom Embedding Full Dataset Testing Results===============")
display(cust_emb_by_full_data_test_results.head())
# Out:
# (1, 11)
# ==============step5_1_1- NCF Model: Custom Embedding Full Dataset Validation Results===============
#         mse     rmse   ndcg@10  precision@10  recall@10     f1@10  \
# 0  0.892829  0.94476  0.996364      0.867375   0.876889  0.870588
#
#    embedding_dim  learning_rate  batch_size  dropout_rate  num_epochs
# 0              6          0.001         128           0.0          20
# (1, 11)
# ==============step5_1_1- NCF Model: Custom Embedding Full Dataset Testing Results===============
#         mse      rmse   ndcg@10  precision@10  recall@10     f1@10  \
# 0  1.859998  1.192249  0.971615      0.859671   0.934425  0.884954
#
#    embedding_dim  learning_rate  batch_size  dropout_rate  num_epochs
# 0              6          0.001         128           0.0          20

# %%
# step5_1_2 - NCF Model: Custom Embedding By Cluster
cust_emb_by_cluster_val_results = pd.read_csv(os.path.join(results_dir,"NCF Custom Embedding/Clustered Model/val_results_by_cluster.csv"))
print(cust_emb_by_cluster_val_results.shape)
print("==========step5_1_2 - NCF Model: Custom Embedding By Cluster Validation Results==========")
display(cust_emb_by_cluster_val_results.head())


cust_emb_by_cluster_test_results = pd.read_csv(os.path.join(results_dir,"NCF Custom Embedding/Clustered Model/test_results_by_cluster.csv"))
print(cust_emb_by_cluster_test_results.shape)
print("==========step5_1_2 - NCF Model: Custom Embedding By Cluster Test Results==========")
display(cust_emb_by_cluster_test_results.head())

print("Average Validation Metrics:")
print(cust_emb_by_cluster_val_results.mean(numeric_only=True))

# Compute average metrics across clusters for test results
print("\nAverage Test Metrics:")
print(cust_emb_by_cluster_test_results.mean(numeric_only=True))
# Out:
# (4, 13)
# ==========step5_1_2 - NCF Model: Custom Embedding By Cluster Validation Results==========
#    cluster_id       mse      rmse   ndcg@10  precision@10  recall@10  \
# 0           0  0.817287  0.904039  0.996735      0.888622   0.896832
# 1           1  2.007905  1.417006  1.000000      0.642157   0.642157
# 2           2  0.695792  0.834141  0.974441      0.906701   0.953757
# 3           3  0.550171  0.741735  1.000000      0.933949   0.933949
#
#       f1@10  embedding_dim  learning_rate  batch_size  dropout_rate  \
# 0  0.891358              5          0.001         512           0.0
# 1  0.642157              5          0.001         512           0.0
# 2  0.922668              5          0.001         512           0.0
# 3  0.933949              5          0.001         512           0.0
#
#    num_epochs  train_time_sec
# 0          40          195.19
# 1          40           60.92
# 2          40           57.76
# 3          40          138.14
# (4, 12)
# ...

# %%
#step5_2_1- NCF Model: Random Embeddings Full Dataset
rand_emb_full_data_val_results = pd.read_csv(os.path.join(results_dir,"NCF Random Embedding/Full Model/val_results_full_dataset.csv"))
print(rand_emb_full_data_val_results.shape)
print("============step5_2_1- NCF Model: Random Embeddings Full Dataset Validation Results============")
display(rand_emb_full_data_val_results)


rand_emb_by_full_data_test_results = pd.read_csv(os.path.join(results_dir,"NCF Random Embedding/Full Model/test_results_full_dataset.csv"))
print(rand_emb_by_full_data_test_results.shape)
print("===========step5_2_1- NCF Model: Random Embeddings Full Dataset Test Results============")
display(rand_emb_by_full_data_test_results)
# Out:
# (1, 11)
# ============step5_2_1- NCF Model: Random Embeddings Full Dataset Validation Results============
#        rmse       mse  ndcg@10  precision@10  recall@10     f1@10  \
# 0  0.989009  0.975591  0.99579      0.867375   0.876889  0.870588
#
#    embedding_dim  learning_rate  batch_size  dropout_rate  num_epochs
# 0             64          0.001         128           0.3          40
# (1, 11)
# ===========step5_2_1- NCF Model: Random Embeddings Full Dataset Test Results============
#        rmse       mse   ndcg@10  precision@10  recall@10     f1@10  \
# 0  1.078569  1.162062  0.971801      0.859677   0.934431  0.884957
#
#    embedding_dim  learning_rate  batch_size  dropout_rate  num_epochs
# 0             64          0.001         128           0.3          40

# %%
# step5_2_2 - NCF Model: Random Embeddings By Cluster
rand_emb_clustered_data_val_results = pd.read_csv(os.path.join(results_dir,"NCF Random Embedding/Clustered Model/val_results_by_cluster.csv"))
print(rand_emb_clustered_data_val_results.shape)
print("===========step5_2_2 - NCF Model: Random Embeddings By Cluster Validation Results===========")
display(rand_emb_clustered_data_val_results)


rand_emb_by_clustered_data_test_results = pd.read_csv(os.path.join(results_dir,"NCF Random Embedding/Clustered Model/test_results_by_cluster.csv"))
print(rand_emb_by_clustered_data_test_results.shape)
print("===========step5_2_2 - NCF Model: Random Embeddings By Cluster Test Results===========")
display(rand_emb_by_clustered_data_test_results)

print("Average Validation Metrics:")
print(rand_emb_clustered_data_val_results.mean(numeric_only=True))

print("\nAverage Test Metrics:")
print(rand_emb_by_clustered_data_test_results.mean(numeric_only=True))
# Out:
# (4, 12)
# ===========step5_2_2 - NCF Model: Random Embeddings By Cluster Validation Results===========
#    cluster_id      rmse       mse   ndcg@10  precision@10  recall@10  \
# 0           0  0.912108  0.831512  0.996856      0.888622   0.896832
# 1           1  1.481553  2.167412  1.000000      0.642157   0.642157
# 2           2  0.888148  0.777309  0.976638      0.906701   0.953757
# 3           3  0.734164  0.548259  1.000000      0.933949   0.933949
#
#       f1@10  embedding_dim  learning_rate  batch_size  dropout_rate  \
# 0  0.891358             16          0.001         128           0.3
# 1  0.642157             16          0.001         128           0.3
# 2  0.922668             16          0.001         128           0.3
# 3  0.933949             16          0.001         128           0.3
#
#    num_epochs
# 0          20
# 1          20
# 2          20
# 3          20
# (4, 12)
# ===========step5_2_2 - NCF Model: Random Embeddings By Cluster Test Results===========
# ...

# %%
# step5_3_NCF_negative_sampling results

neg_sampling_val_results = pd.read_csv(os.path.join(results_dir, 'NCF Negative Sampling/full_model_validation_results.csv'))
print(neg_sampling_val_results.shape)
print("===========step5_3_NCF_negative_sampling Validation Results===========")
display(neg_sampling_val_results)

neg_sampling_test_results = pd.read_csv(os.path.join(results_dir, 'NCF Negative Sampling/full_model_testing_results.csv'))
print(neg_sampling_test_results.shape)
print("===========step5_3_NCF_negative_sampling Test Results===========")
display(neg_sampling_test_results)
# Out:
# (1, 6)
# ===========step5_3_NCF_negative_sampling Validation Results===========
#         mse     rmse   ndcg@10  precision@10  recall@10     f1@10
# 0  1.377921  0.56618  0.788729      0.577245    0.86883  0.674588
# (1, 6)
# ===========step5_3_NCF_negative_sampling Test Results===========
#         mse      rmse   ndcg@10  precision@10  recall@10     f1@10
# 0  1.266877  0.550884  0.846563      0.595341   0.945082  0.713955

# %%
# step5_4_Hybrid_NCF_Model Results

base_dir = '/content/drive/MyDrive/bt4222_group_6/bt4222_group_6_amazon/Model Results/NCF Hybrid Embedding'
cluster_ids = sorted([int(d.split('_')[1]) for d in os.listdir(base_dir) if d.startswith('Cluster_')])

# Collect results
val_results_all = []
test_results_all = []

for cid in cluster_ids:
    cluster_dir = os.path.join(base_dir, f'Cluster_{cid}')

    # Load and tag val results
    val_path = os.path.join(cluster_dir, 'val_results_by_cluster.csv')
    if os.path.exists(val_path):
        df_val = pd.read_csv(val_path)
        df_val.insert(0, 'cluster_id', cid)
        val_results_all.append(df_val)

    # Load and tag test results
    test_path = os.path.join(cluster_dir, 'test_results_by_cluster.csv')
    if os.path.exists(test_path):
        df_test = pd.read_csv(test_path)
        df_test.insert(0, 'cluster_id', cid)
        test_results_all.append(df_test)

# Combine into two dataframes
val_df = pd.concat(val_results_all, ignore_index=True)
test_df = pd.concat(test_results_all, ignore_index=True)

# Print Results
print("========step5_4_Hybrid_NCF_Model Validation Results by Cluster:========")
display(val_df)

print("========step5_4_Hybrid_NCF_Model Test Results by Cluster:========")
display(test_df)

print("Average Validation Metrics:")
print(val_df.mean(numeric_only=True))

print("\nAverage Test Metrics:")
print(test_df.mean(numeric_only=True))
# Out:
# ========step5_4_Hybrid_NCF_Model Validation Results by Cluster:========
#    cluster_id       mse      rmse   ndcg@10  precision@10  recall@10  \
# 0           0  0.775750  0.880766  0.997122      0.888622   0.896832
# 1           1  2.091425  1.446176  1.000000      0.642157   0.642157
# 2           2  0.624575  0.790301  0.978815      0.906701   0.953757
# 3           3  0.521583  0.722207  1.000000      0.933949   0.933949
#
#       f1@10  custom_embedding_dim  random_embedding_dim  custom_dropout_rate  \
# 0  0.891358                     5                     8                  0.3
# 1  0.642157                     5                     5                  0.0
# 2  0.922668                     5                     8                  0.3
# 3  0.933949                     6                     5                  0.0
#
#    random_dropout_rate  custom_learning_rate  random_learning_rate  \
# 0                  0.0                 0.001                 0.001
# ...
